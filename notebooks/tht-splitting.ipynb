# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


plt.style.use('fivethirtyeight')

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
df = pd.read_pickle("../container-data/df.pkl")

# %%
df.describe()
# Out:
#        Bolt_1_Tensile  Bolt_2_Tensile  Bolt_3_Tensile  Bolt_4_Tensile  \
# count    1.035745e+07    1.035745e+07    1.035745e+07    1.035745e+07
# mean     1.524169e+03    1.455752e+03    1.642058e+03    1.598662e+03
# std      4.775116e+01    1.977411e+01    3.055374e+01    3.771960e+00
# min      1.381212e+03    1.363846e+03    1.545338e+03    1.534797e+03
# 25%      1.487370e+03    1.439192e+03    1.612892e+03    1.595825e+03
# 50%      1.498797e+03    1.449805e+03    1.639057e+03    1.598274e+03
# 75%      1.556153e+03    1.468664e+03    1.666389e+03    1.600880e+03
# max      1.640510e+03    1.505455e+03    1.702324e+03    1.608715e+03
#
#        Bolt_5_Tensile  Bolt_6_Tensile  Unit_4_Power  Unit_4_Reactive Power  \
# count    1.035745e+07    1.035745e+07  1.035745e+07           1.035745e+07
# mean     1.631655e+03    1.650944e+03  2.909581e+02           8.366633e+00
# std      7.306725e+00    1.862302e+01  3.367793e+01           1.629949e+01
# ...

# %%
df = df.sort_index()

# %%
df.isnull().sum()
# Out:
# Bolt_1_Tensile                    124087
# Bolt_2_Tensile                    124087
# Bolt_3_Tensile                    124087
# Bolt_4_Tensile                    124087
# Bolt_5_Tensile                    124087
# Bolt_6_Tensile                    124087
# Unit_4_Power                      124087
# Unit_4_Reactive Power             124087
# Turbine_Guide Vane Opening        124087
# Turbine_Pressure Drafttube        124087
# Turbine_Pressure Spiral Casing    124087
# Turbine_Rotational Speed          124087
# mode                                   0
# dtype: int64

# %%
nrow= 3
ncol=2

# make a list of all dataframes 
fig, axes = plt.subplots(nrow, ncol, figsize=(16,12))

# plot counter
count=1
for r in range(nrow):
    for c in range(ncol):
        df["Bolt_"+str(count)+"_Tensile"].plot(ax=axes[r,c], )
        count+=1

# %%
df["Unit_4_Power"].cumsum().plot()
# Out:
# <AxesSubplot:xlabel='timepoints'>

# %%
df.shape
# Out:
# (10481533, 13)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (10357446, 13)

# %%
df.describe()
# Out:
#        Bolt_1_Tensile  Bolt_2_Tensile  Bolt_3_Tensile  Bolt_4_Tensile  \
# count    1.035745e+07    1.035745e+07    1.035745e+07    1.035745e+07
# mean     1.524169e+03    1.455752e+03    1.642058e+03    1.598662e+03
# std      4.775116e+01    1.977411e+01    3.055374e+01    3.771960e+00
# min      1.381212e+03    1.363846e+03    1.545338e+03    1.534797e+03
# 25%      1.487370e+03    1.439192e+03    1.612892e+03    1.595825e+03
# 50%      1.498797e+03    1.449805e+03    1.639057e+03    1.598274e+03
# 75%      1.556153e+03    1.468664e+03    1.666389e+03    1.600880e+03
# max      1.640510e+03    1.505455e+03    1.702324e+03    1.608715e+03
#
#        Bolt_5_Tensile  Bolt_6_Tensile  Unit_4_Power  Unit_4_Reactive Power  \
# count    1.035745e+07    1.035745e+07  1.035745e+07           1.035745e+07
# mean     1.631655e+03    1.650944e+03  2.909581e+02           8.366633e+00
# std      7.306725e+00    1.862302e+01  3.367793e+01           1.629949e+01
# ...

# %%
df.shape
# Out:
# (10357446, 13)

# %%
df.head()
# Out:
#          Bolt_1_Tensile  Bolt_2_Tensile  Bolt_3_Tensile  Bolt_4_Tensile  \
# int_ind
# 0           1405.125823     1364.298361     1545.338423     1541.879099
# 1           1414.472359     1369.287791     1549.648881     1547.591601
# 2           1416.526738     1370.435669     1550.420271     1548.632153
# 3           1417.425442     1370.953391     1550.729481     1549.060964
# 4           1418.311627     1371.439562     1551.064989     1549.477768
#
#          Bolt_5_Tensile  Bolt_6_Tensile  Unit_4_Power  Unit_4_Reactive Power  \
# int_ind
# 0           1523.484042     1503.087832           0.0              -1.407876
# 1           1531.876456     1518.719841           0.0              -1.425341
# 2           1533.457978     1522.138148           0.0              -1.442806
# 3           1534.171959     1523.589704           0.0              -1.460271
# 4           1534.817494     1524.958113           0.0              -1.477737
#
# ...

# %%
df["mode"] = df["mode"].apply(lambda x: 1 if x=="start" else 0)

# %%
df["mode"].tail(1000000).plot()
# Out:
# <AxesSubplot:xlabel='timepoints'>

# %%
df["Unit_4_Power"].tail(1000000).plot()
# Out:
# <AxesSubplot:xlabel='timepoints'>

# %%
df["Turbine_Guide Vane Opening"].tail(1000000).plot()
# Out:
# <AxesSubplot:xlabel='timepoints'>

# %%
def split_trn_val(df, frac=0.2):
    df = df.copy()
    df.index = np.arange(len(df))
    val_inds = np.random.choice(df.index.values, size=int(len(df)*0.2), replace=False)
    val_df = df.iloc[df.index.isin(val_inds)]
    trn_df = df.iloc[~df.index.isin(val_inds)]
    return trn_df, val_df

# %%
trn_df, val_df = split_trn_val(df)

# %%
trn_df.shape, val_df.shape
# Out:
# ((8385227, 13), (2096306, 13))

# %%
len(val_df)+len(trn_df)
# Out:
# 10481533
