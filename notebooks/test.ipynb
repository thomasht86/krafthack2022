# %%
import pandas as pd
import numpy as np
import stumpy
import sklearn
import lightgbm
import xgboost
import skforecast
import statsmodels
import tsfresh

# %%
from tsfresh.examples.robot_execution_failures import download_robot_execution_failures, \
    load_robot_execution_failures

download_robot_execution_failures()
timeseries, y = load_robot_execution_failures()

# %%
df = pd.DataFrame(timeseries)

# %%
df
# Out:
#       id  time  F_x  F_y  F_z  T_x  T_y  T_z
# 0      1     0   -1   -1   63   -3   -1    0
# 1      1     1    0    0   62   -3   -1    0
# 2      1     2   -1   -1   61   -3    0    0
# 3      1     3   -1   -1   63   -2   -1    0
# 4      1     4   -1   -1   63   -3   -1    0
# ...   ..   ...  ...  ...  ...  ...  ...  ...
# 1315  88    10  -10    2   39  -21  -24    5
# 1316  88    11  -11    2   38  -24  -22    6
# 1317  88    12  -12    3   23  -24  -24    5
# 1318  88    13  -13    4   26  -29  -27    5
# 1319  88    14  -13    2   15  -25  -25    6
#
# [1320 rows x 8 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
matrix = stumpy.stump(df.F_z.astype(np.float64), 5, df.T_y.astype(np.float64))

# %%
df_m = pd.DataFrame(matrix, columns=["mp", "inds", "l_inds", "r_inds"])

# %%
df_m["mp"].plot()
# Out:
# <AxesSubplot:>
