# %%
import pandas as pd
import numpy as np
import stumpy
import sklearn
import lightgbm
import xgboost
import skforecast
import statsmodels

# %%
your_time_series = np.random.rand(1000)
window_size = 50  # Approximately, how many data points might be found in a pattern
matrix_profile = stumpy.stump(your_time_series, m=window_size)

# %%
df = pd.DataFrame(matrix_profile)

# %%
df.iloc[:,0].plot(label="matrix profile")
# Out:
# <AxesSubplot:>
